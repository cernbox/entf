# %%
from ROOT_testing import Experiment


# Experiment class:
# __init__(self, folder_in, folder_out=CWD, ttype=None, exclude_list=None, sanity_check=False, gt_fname=None, to_grafana=False):

# Testing io tutorials
print "\nRunning IO tutorials..."
EXCLUDE_IO = ["copyFiles.C.nbconvert.ipynb", "mergeSelective.C.nbconvert.ipynb"]
io_test = Experiment("converted_notebooks/io", ttype="io", exclude_list=EXCLUDE_IO, \
                     sanity_check=True, gt_fname="push_to_monitor.groundtruth", to_grafana=False)
io_test.run()


# Testing math tutorials
print "\nRunning MATH tutorials..."
EXCLUDE_MATH = ["testUnfold2.C.nbconvert.ipynb", "testUnfold4.C.nbconvert.ipynb", "testUnfold5d.C.nbconvert.ipynb", "testrandom.C.nbconvert.ipynb"]
math_test = Experiment("converted_notebooks/math", ttype="math", exclude_list=EXCLUDE_MATH, \
                       sanity_check=True, gt_fname="push_to_monitor.groundtruth", to_grafana=False)
math_test.run()

# Testing tree tutorials
print "\nRunning TREE tutorials..."
EXCLUDE_TREE = ["copytree.C.nbconvert.ipynb", "copytree2.C.nbconvert.ipynb", "copytree3.C.nbconvert.ipynb", "hsimpleProxyDriver.C.nbconvert.ipynb", "htest.C.nbconvert.ipynb", "run_h1analysis.C.nbconvert.ipynb"]
tree_test = Experiment("converted_notebooks/tree", ttype="tree", exclude_list=EXCLUDE_TREE, \
                       sanity_check=True, gt_fname="push_to_monitor.groundtruth", to_grafana=False)
tree_test.run()
# Out:
# Running IO tutorials...
# Notebooks detected: 11
# 	Running: dirs.C.nbconvert.ipynb
# 	Running: double32.C.nbconvert.ipynb
# 	Running: fildir.C.nbconvert.ipynb
# 	Running: file.C.nbconvert.ipynb
# 	Running: hadd.C.nbconvert.ipynb
# 	Running: importCode.C.nbconvert.ipynb
# 	Running: loopdir.C.nbconvert.ipynb
# 	Running: readCode.C.nbconvert.ipynb
# 	Running: testMergeCont.C.nbconvert.ipynb
# Done with the notebooks.
# Sanity check.
#
# Running MATH tutorials...
# Notebooks detected: 45
# 	Running: Bessel.C.nbconvert.ipynb
# 	Running: ChebyshevPol.C.nbconvert.ipynb
# 	Running: CrystalBall.C.nbconvert.ipynb
# 	Running: FeldmanCousins.C.nbconvert.ipynb
# 	Running: GammaFun.C.nbconvert.ipynb
# 	Running: Legendre.C.nbconvert.ipynb
# 	Running: LegendreAssoc.C.nbconvert.ipynb
# 	Running: Rolke.C.nbconvert.ipynb
# 	Running: TSVDUnfoldExample.C.nbconvert.ipynb
# 	Running: binomial.C.nbconvert.ipynb
# 	Running: chi2test.C.nbconvert.ipynb
# 	Running: exampleFunctor.C.nbconvert.ipynb
# ...
